# %%
mlist = [1,2,3,4,5]
mlist.insert(2,6) #inserta elemento 6 en la posición con index 2
mlist
# Out:
# [1, 2, 6, 3, 4, 5]

# %%
mlist
# Out:
# [1, 2, 6, 3, 4, 5]

# %%
mlist.pop(-1),mlist #elimina el elemento de la posicion indicada
# Out:
# (5, [1, 2, 6, 3, 4])

# %%
mlist.remove(6)
mlist
# Out:
# [1, 2, 3, 4]

# %%
mlist.reverse()
mlist
# Out:
# [4, 3, 2, 1]

# %%
mlist.sort()
mlist
# Out:
# [1, 2, 3, 4]

# %%
mlist.sort(reverse=True)
mlist
# Out:
# [4, 3, 2, 1]

# %%
tuplee = ('1','2','6','1','1')
tuplee.index('1') #el indice de la primera vez que aparece el elemento
# Out:
# 0

# %%
len(tuplee)
# Out:
# 5

# %%
dictt={'A':4,'B':6}

# %%
list(dictt.keys())
# Out:
# ['A', 'B']

# %%
s = set([1,4,5,6,6,9])
s
# Out:
# {1, 4, 5, 6, 9}

# %%
s.add(7)

# %%
s
# Out:
# {1, 4, 5, 6, 7, 9}
